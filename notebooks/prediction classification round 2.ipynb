# %%
import warnings
warnings.filterwarnings("ignore")

import numpy as np
import pandas as pd
import gzip
import json
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
    LabelEncoder,
    StandardScaler
)
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report
import nltk
from nltk.corpus import stopwords
from imblearn.combine import SMOTEENN

# Download stopwords
nltk.download('stopwords')
turkish_stopwords = stopwords.words('turkish')

# -----------------------------
# 1. Load Your Data
# -----------------------------
df1 = pd.read_csv("annotated_users_4.csv")

df2 = pd.read_csv("annotated_users_1.csv")
df3 = pd.read_csv("annotated_users_2.csv")
df4 = pd.read_csv("annotated_users_3.csv")

frames = [df2, df3, df4]
df = pd.concat(frames, ignore_index=True)

columns_to_drop = ['url', 'influencerMention', 'accountType']

def clean_data(df):
    return df.drop(columns=columns_to_drop)

df = clean_data(df)

frames = [df, df1]
final_df = pd.concat(frames, ignore_index=True)

# Remove duplicates and NaN
final_df.drop_duplicates(inplace=True)
final_df.dropna(inplace=True)

# Capitalize influencerCategory
final_df['influencerCategory'] = final_df['influencerCategory'].str.capitalize()

# Drop certain classes
classes_to_drop = ['Gaming']
final_df = final_df[~final_df['influencerCategory'].isin(classes_to_drop)]

print(f'The cleaned data has {final_df.shape[0]} rows and {final_df.shape[1]} columns')

# -----------------------------
# 2. Define Username Cleaning
# -----------------------------
def clean_username(username):
    """
    Comprehensive username cleaning function that:
    1. Removes numbers
    2. Removes punctuation
    3. Removes stop words (English)
    4. Removes special characters
    5. Replaces common separators with space
    """
    # Convert to lowercase
    username = str(username).lower()

    # Replace common separators with space
    username = re.sub(r'[._-]', ' ', username)

    # Remove numbers
    username = re.sub(r'\d+', '', username)

    # Remove punctuation
    username = username.translate(str.maketrans('', '', string.punctuation))

    # Split into words
    words = username.split()

    # Remove English stop words
    stop_words = set(stopwords.words('english'))
    words = [word for word in words if word not in stop_words]

    # Remove very short terms (likely not meaningful)
    words = [word for word in words if len(word) > 2]

    # Join words back together
    clean_u = ' '.join(words)

    # Remove any remaining special characters
    clean_u = re.sub(r'[^a-zA-Z\s]', '', clean_u)

    return clean_u.strip()

def preprocess_data(df):
    """
    Preprocess the entire dataset:
     - Clean usernames
     - Filter out empty processed usernames
    """
    processed_df = df.copy()
    processed_df['processed_username'] = processed_df['username'].apply(clean_username)
    processed_df = processed_df[processed_df['processed_username'].str.len() > 0].reset_index(drop=True)
    return processed_df

new_df = preprocess_data(final_df)

# Keep only the processed_username and influencerCategory in that order
new_df = new_df.reindex(columns=['processed_username', 'influencerCategory'])

print("\nProcessed DataFrame:")
print(new_df.head())

# -----------------------------
# 3. TF-IDF Vectorizer and Encoding
# -----------------------------
tfidf = TfidfVectorizer(
    analyzer='char_wb', 
    ngram_range=(2, 5),
    min_df=3,  
    max_df=0.9,  
    sublinear_tf=True,  
    max_features=10000, 
    stop_words=turkish_stopwords  
)

X = tfidf.fit_transform(new_df['processed_username'])
print(f"\nTF-IDF Matrix Shape: {X.shape}")  

# Scale
scaler = StandardScaler(with_mean=False)
X = scaler.fit_transform(X)

# Label encode influencerCategory
le = LabelEncoder()
y = le.fit_transform(new_df['influencerCategory'])

# -----------------------------
# 4. Handle Imbalance + Split
# -----------------------------
smote = SMOTEENN(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

X_train, X_test, y_train, y_test = train_test_split(
    X_resampled, 
    y_resampled, 
    train_size=0.8, 
    stratify=y_resampled, 
    random_state=2022
)

# -----------------------------
# 5. Train Multiple Classifiers
# -----------------------------
classifiers = {
    'Random Forest': RandomForestClassifier(
        n_estimators=200,
        max_depth=20,
        min_samples_split=5,
        min_samples_leaf=2,
        class_weight='balanced',
        random_state=42
    ),
    'SVM': SVC(kernel='linear', random_state=42),
    'Naive Bayes': MultinomialNB(),
    'Logistic Regression': LogisticRegression(max_iter=1000, random_state=42),
    'Gradient Boosting': GradientBoostingClassifier(random_state=42)
}

results = {}
best_classifier_name = None
best_accuracy = 0
best_model = None

for name, clf in classifiers.items():
    clf.fit(X_train, y_train)
    y_train_pred = clf.predict(X_train)
    y_test_pred = clf.predict(X_test)
    train_accuracy = accuracy_score(y_train, y_train_pred)
    test_accuracy = accuracy_score(y_test, y_test_pred)
    results[name] = {
        'train_accuracy': train_accuracy,
        'test_accuracy': test_accuracy,
        'report': classification_report(y_test, y_test_pred, target_names=le.classes_)
    }
    if test_accuracy > best_accuracy:
        best_accuracy = test_accuracy
        best_classifier_name = name
        best_model = clf

print("\nClassification Results:\n")
for name, result in results.items():
    print(f"\n{name}:")
    print(f"Training Accuracy: {result['train_accuracy']:.4f}")
    print(f"Testing Accuracy: {result['test_accuracy']:.4f}")
    print("\nDetailed Classification Report:")
    print(result['report'])

print(f"\nBest Classifier: {best_classifier_name} with accuracy: {best_accuracy:.4f}")

# -----------------------------
# 6. Save Predictions to JSON (Internal Test Split) - Removed to Avoid Errors
# -----------------------------
# The following section has been removed to prevent the "positional indexers are out-of-bounds" error.
# It attempted to map predictions back to usernames using incorrect indices.

# If you still need to map predictions to usernames for the internal test split,
# consider alternative approaches such as tracking indices before resampling.

# -----------------------------
# 7. Read the New Test File and Predict
# -----------------------------
def predict_and_save_new_data(test_file, model, tfidf_vectorizer, data_scaler, label_encoder, output_file="outputclassification.json"):
    """
    Reads usernames from `test_file`, cleans them, 
    transforms them using the fitted pipeline, 
    predicts categories, and saves to JSON.
    """
    # Read lines from the test file
    with open(test_file, 'r', encoding='utf-8') as f:
        test_usernames = f.read().splitlines()
    
    # Clean each username
    cleaned_test_usernames = [clean_username(u) for u in test_usernames]
    
    # Transform with existing TF-IDF and scaler
    X_test_transformed = tfidf_vectorizer.transform(cleaned_test_usernames)
    X_test_transformed = data_scaler.transform(X_test_transformed)
    
    # Predict
    y_preds = model.predict(X_test_transformed)
    # Convert numeric predictions back to category names
    category_preds = label_encoder.inverse_transform(y_preds)
    
    # Build dictionary {original_username: predicted_category}
    results_dict = {}
    for original, pred in zip(test_usernames, category_preds):
        results_dict[original] = pred
    
    # Save to JSON
    with open(output_file, 'w', encoding='utf-8') as json_file:
        json.dump(results_dict, json_file, indent=4, ensure_ascii=False)
    
    print(f"Predictions have been saved to {output_file}")
    return results_dict

# Use the best model found
predict_and_save_new_data(
    test_file="test-classification-round3.dat",
    model=best_model,
    tfidf_vectorizer=tfidf,
    data_scaler=scaler,
    label_encoder=le,
    output_file="outputclassification.json"
)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/aminzaka/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# The cleaned data has 2977 rows and 2 columns
#
# Processed DataFrame:
#     processed_username influencerCategory
# 0       ozlem ozdemirr      Entertainment
# 1        caglaralmendi            Fashion
# 2  modabelliniofficial            Fashion
# 3            bkmonline      Entertainment
# 4         minikkusblog   Mom and children
#
# TF-IDF Matrix Shape: (2973, 7981)
#
# Classification Results:
#
#
# Random Forest:
# Training Accuracy: 0.9194
# Testing Accuracy: 0.8295
#
# Detailed Classification Report:
#                       precision    recall  f1-score   support
#
#                  Art       0.98      0.81      0.89        77
#        Entertainment       0.80      0.83      0.81        29
#              Fashion       0.68      0.84      0.75        55
#                 Food       0.53      0.71      0.61        14
# Health and lifestyle       1.00      0.75      0.86         4
#     Mom and children       0.97      0.84      0.90        92
#               Sports       0.95      0.82      0.88        98
#                 Tech       0.60      0.91      0.72        55
#               Travel       0.92      0.82      0.87        57
#
#             accuracy                           0.83       481
#            macro avg       0.83      0.81      0.81       481
#         weighted avg       0.86      0.83      0.84       481
#
#
# SVM:
# Training Accuracy: 1.0000
# Testing Accuracy: 0.9792
#
# Detailed Classification Report:
#                       precision    recall  f1-score   support
#
#                  Art       0.95      0.97      0.96        77
#        Entertainment       0.96      0.90      0.93        29
#              Fashion       0.96      0.98      0.97        55
#                 Food       1.00      0.93      0.96        14
# Health and lifestyle       1.00      0.75      0.86         4
#     Mom and children       0.97      0.99      0.98        92
#               Sports       1.00      1.00      1.00        98
#                 Tech       1.00      0.98      0.99        55
#               Travel       1.00      1.00      1.00        57
#
#             accuracy                           0.98       481
#            macro avg       0.98      0.94      0.96       481
#         weighted avg       0.98      0.98      0.98       481
#
#
# Naive Bayes:
# Training Accuracy: 0.9964
# Testing Accuracy: 0.9647
#
# Detailed Classification Report:
#                       precision    recall  f1-score   support
#
#                  Art       0.96      0.92      0.94        77
#        Entertainment       0.87      0.90      0.88        29
#              Fashion       0.98      0.96      0.97        55
#                 Food       1.00      0.93      0.96        14
# Health and lifestyle       0.44      1.00      0.62         4
#     Mom and children       0.99      1.00      0.99        92
#               Sports       1.00      0.98      0.99        98
#                 Tech       0.98      0.98      0.98        55
#               Travel       0.96      0.96      0.96        57
#
#             accuracy                           0.96       481
#            macro avg       0.91      0.96      0.92       481
#         weighted avg       0.97      0.96      0.97       481
#
#
# Logistic Regression:
# Training Accuracy: 1.0000
# Testing Accuracy: 0.9813
#
# Detailed Classification Report:
#                       precision    recall  f1-score   support
#
#                  Art       0.95      0.97      0.96        77
#        Entertainment       1.00      0.90      0.95        29
#              Fashion       0.98      0.98      0.98        55
#                 Food       1.00      0.93      0.96        14
# Health and lifestyle       1.00      0.75      0.86         4
#     Mom and children       0.97      1.00      0.98        92
#               Sports       1.00      1.00      1.00        98
#                 Tech       1.00      0.98      0.99        55
#               Travel       0.98      1.00      0.99        57
#
#             accuracy                           0.98       481
#            macro avg       0.99      0.95      0.96       481
#         weighted avg       0.98      0.98      0.98       481
#
#
# Gradient Boosting:
# Training Accuracy: 1.0000
# Testing Accuracy: 0.9002
#
# Detailed Classification Report:
#                       precision    recall  f1-score   support
#
#                  Art       0.93      0.90      0.91        77
#        Entertainment       1.00      0.83      0.91        29
#              Fashion       0.98      0.85      0.91        55
#                 Food       0.93      0.93      0.93        14
# Health and lifestyle       1.00      0.75      0.86         4
#     Mom and children       0.94      0.87      0.90        92
#               Sports       0.75      0.97      0.85        98
#                 Tech       0.91      0.95      0.93        55
#               Travel       1.00      0.88      0.93        57
#
#             accuracy                           0.90       481
#            macro avg       0.94      0.88      0.90       481
#         weighted avg       0.91      0.90      0.90       481
#
#
# Best Classifier: Logistic Regression with accuracy: 0.9813
# Predictions have been saved to outputclassification.json
# {'livapastanesi': 'Health and lifestyle',
#  'barisgross': 'Travel',
#  'tusasshop': 'Fashion',
#  'etolyadigital': 'Tech',
#  'tugrulonur': 'Travel',
#  'tulugozlu': 'Art',
#  'gokidy': 'Mom and children',
#  'cengizgumus_official': 'Entertainment',
#  'krossbisiklet': 'Tech',
#  'haribochamallows': 'Art',
#  'ozatashipyard': 'Art',
#  'yenisafak': 'Sports',
#  'iamsiddeshjadhav': 'Art',
#  'burcinterzioglu': 'Fashion',
#  'steakhousegunaydin': 'Travel',
#  'baselifeclub': 'Travel',
#  'benismailyildirimm': 'Tech',
#  'imuneksfarma': 'Tech',
#  'dogakoyucatalca': 'Tech',
#  'sena.sener': 'Fashion',
#  'kandilliborsarestaurant': 'Food',
#  'selamiersoyy': 'Sports',
#  'deutz_fahr_turkey': 'Tech',
#  'cevaheer': 'Fashion',
#  'tezatsanat': 'Art',
#  'filtresizcom': 'Fashion',
#  'palomamarina_suites': 'Travel',
#  'westchocolatemarina': 'Travel',
#  'sebnemcapa': 'Travel',
#  'rozetsepeti': 'Entertainment',
#  'ececesmioglu': 'Fashion',
#  'ustapidecitr': 'Travel',
#  'gocaagonyali': 'Sports',
#  'maestro.sanat.kursu': 'Art',
#  'oztayteksofficial': 'Fashion',
#  'imtolstoyevski': 'Tech',
#  'turkervip': 'Travel',
#  'rustik.rus.restorani': 'Fashion',
#  'guzellik_hemsiresi': 'Fashion',
#  'mehmetcikvakfi': 'Mom and children',
#  'bruderturkiye': 'Tech',
#  'brandingturkiye': 'Tech',
#  'dogushyilmaz': 'Art',
#  'crmbelediyesi': 'Mom and children',
#  'gcaturkiye': 'Tech',
#  'bskcemildeveci': 'Tech',
#  'lokmanhekimhastaneleri': 'Health and lifestyle',
#  'trumpavm': 'Entertainment',
#  'resimlimagnet_com': 'Fashion',
#  'ilaydaakdogan': 'Fashion',
#  'karincaproduksiyon': 'Travel',
#  'ilkergodencemobilya': 'Art',
#  'semihasahin': 'Sports',
#  'ogretmeninkaleminden_': 'Sports',
#  'narkoyjournal': 'Entertainment',
#  'kuzucu_mucevherat': 'Fashion',
#  'mmkmetalurji': 'Tech',
#  'okanyanmazcom': 'Fashion',
#  'silopibld': 'Mom and children',
#  'cubocomtr': 'Travel',
#  'ahlatbld': 'Travel',
#  'tarimoz': 'Art',
#  'komunpub': 'Food',
#  'novax_gozluk_camlari': 'Fashion',
#  'tarkan': 'Sports',
#  'sefkatpeker': 'Travel',
#  'kore_kultur_merkezi': 'Travel',
#  'gaiaandco': 'Art',
#  'bvbajans': 'Tech',
#  'esila_kids': 'Mom and children',
#  'halisunasyoncoffee': 'Food',
#  'ecovero.turkey': 'Tech',
#  'denizliotizmdernegi': 'Mom and children',
#  'buckheadturkey': 'Tech',
#  'karaman.bel.tr': 'Entertainment',
#  'imoykukarayel': 'Sports',
#  'celsuskitabevi': 'Art',
#  'sonerarica1': 'Mom and children',
#  'keyifbebesi': 'Mom and children',
#  'vadistanbul': 'Entertainment',
#  'pivoraizmir': 'Sports',
#  'aliyagciii': 'Sports',
#  'bebebiyat': 'Art',
#  'erdqtr': 'Mom and children',
#  'mo_istanbul': 'Entertainment',
#  'mekpan_panel': 'Tech',
#  'rotarttasarim': 'Travel',
#  'tc_giresunvaliligi': 'Art',
#  'yigitcaliskan_': 'Tech',
#  'craftdesignistanbul': 'Entertainment',
#  'jciistanbul': 'Entertainment',
#  'mustafakoleoglu': 'Entertainment',
#  'ankarabbld': 'Travel',
#  'staynewinn': 'Fashion',
#  'hasvetmedikal': 'Sports',
#  'trendysidebeach': 'Travel',
#  'promosyonizmir': 'Travel',
#  'turkiyekickboksfederasyonu': 'Sports',
#  'tugcedural': 'Art',
#  'nestleturkiye': 'Tech',
#  'bomotorsport': 'Sports',
#  'ahmetmaranki': 'Entertainment',
#  'hayalevent': 'Entertainment',
#  'ozelkonakhastanesi': 'Health and lifestyle',
#  'istanbul_halidunyasi': 'Food',
#  'adiyaman_park_avm': 'Entertainment',
#  'pillavidenizli': 'Fashion',
#  'annebebekdergisii': 'Mom and children',
#  'enmutluoldugumyer': 'Sports',
#  'alfaglb': 'Sports',
#  'erciyes.anadolu': 'Travel',
#  'dytgozdembasarir': 'Entertainment',
#  'sirenebelekhotel': 'Travel',
#  'ahbap': 'Travel',
#  'uzmanturizm': 'Travel',
#  'cagdasonurozturk': 'Sports',
#  'globaldentaleskisehir': 'Tech',
#  'kilicyarenn': 'Mom and children',
#  'moisahne': 'Entertainment',
#  'thecitysuitestr': 'Travel',
#  'kayihanpala': 'Entertainment',
#  'bilkenttiyatro': 'Art',
#  'kentmeydaniavm': 'Entertainment',
#  'cnridentex': 'Sports',
#  'kirencekaya_balikcisi': 'Tech',
#  'getir': 'Travel',
#  'etimesgutbld': 'Food',
#  'yigitpoyrazz': 'Tech',
#  'gokcinarnecdet': 'Mom and children',
#  'abdullahozdemirbb': 'Mom and children',
#  'babilkulesi_': 'Mom and children',
#  'remedassistance': 'Tech',
#  'mikronajans': 'Tech',
#  'huaweimobiletr': 'Tech',
#  'gezmedenbilemezsin': 'Travel',
#  'coskunaltun36': 'Travel',
#  'lebleukusadasi': 'Mom and children',
#  'schweppes_tr': 'Fashion',
#  'pilatesannesi': 'Mom and children',
#  'livingroomist': 'Travel',
#  'transeshairtransplant': 'Sports',
#  'duygubie': 'Travel',
#  'mylittleponytr': 'Mom and children',
#  'gupseo': 'Art',
#  'erenoren': 'Tech',
#  'kirmiziocakbasi': 'Sports',
#  'duzcehalkmar': 'Travel',
#  'unicosigorta': 'Sports',
#  'gezginsincap': 'Travel',
#  'erkek_bileklik_modelleri': 'Fashion',
#  'yapikredibomontiada': 'Tech',
#  'socratesbistro': 'Sports',
#  'mutfaktayusufvar': 'Food',
#  'digitalagencynetwork': 'Tech',
#  'fiatkastamonugozde': 'Tech',
#  'brkhkmn': 'Tech',
#  'vaziyetcomtr': 'Art',
#  'lisebjkcom': 'Sports',
#  'sinanguler': 'Sports',
#  'mamaspapas.tr': 'Travel',
#  'generalmobile': 'Mom and children',
#  'borusanlojistik': 'Tech',
#  'sana_turkiye': 'Tech',
#  'viptrend.com.tr': 'Art',
#  'artonistanbul': 'Entertainment',
#  'sezergsm38': 'Travel',
#  'resoundturkiye': 'Sports',
#  'tiyatroyeniden_official': 'Art',
#  'barcintancan': 'Sports',
#  'kadindayanismavakfi': 'Mom and children',
#  'serdarsandal35': 'Fashion',
#  'denizcanaktasofficial': 'Fashion',
#  'gulben123': 'Sports',
#  'gezmelerdeyim': 'Travel',
#  'gomecbelediyesi': 'Mom and children',
#  'serpilexclusive': 'Art',
#  'gsb_hatay': 'Sports',
#  'talyakizyurdu': 'Travel',
#  'aycasenbaskan': 'Mom and children',
#  'mandolinyayinlari': 'Art',
#  'sadberkhanimmuzesi': 'Art',
#  'zamanebaba': 'Mom and children',
#  'izzettinyilmaztr': 'Food',
#  'freshscarfs': 'Sports',
#  'pasta34shop': 'Fashion',
#  'webajans': 'Tech',
#  'gci.tuerkei': 'Art',
#  'esseklinik': 'Health and lifestyle',
#  'samuthatr': 'Entertainment',
#  'ozelaydingoz': 'Tech',
#  'iloveanalogue': 'Art',
#  'kadinlarfestivali': 'Art',
#  'braunhouseholdturkey': 'Sports',
#  'este.foot': 'Tech',
#  'uzmananahtar': 'Art',
#  'yorglass': 'Travel',
#  'selcuklukongremerkezi': 'Mom and children',
#  'zerrintekindor': 'Art',
#  'nihatcan11': 'Sports',
#  'sarikizmadensuyu': 'Fashion',
#  'ekremcoskundoner': 'Food',
#  'ilhansen': 'Sports',
#  'hacettepe_university': 'Fashion',
#  'besiktasbelediyesi': 'Sports',
#  'scaniatr': 'Tech',
#  'tosunpasaalacati': 'Sports',
#  'tuna.food': 'Tech',
#  'indirimlix': 'Art',
#  'theurbangoat.ist': 'Entertainment',
#  'kesfetmek_guzeldir': 'Sports',
#  'beko_serdar': 'Mom and children',
#  'mgulluoglu': 'Sports',
#  'muyashop': 'Fashion',
#  'serhanonat': 'Entertainment',
#  'alperenduymaz': 'Art',
#  'tasarimgroup': 'Travel',
#  'ege_koy_mahsulleri': 'Entertainment',
#  'yamalioglumucevherat': 'Fashion',
#  'babylissturkiye': 'Tech',
#  'perlavista_avm': 'Fashion',
#  'dr.gokalpdizdar': 'Mom and children',
#  'kadinkoalisyonu': 'Sports',
#  'acemdenizyel': 'Fashion',
#  'turkerkilic': 'Travel',
#  'gulsenbubikogluofficial': 'Entertainment',
#  'yazyuceil': 'Tech',
#  'kapadokyazeppelin': 'Travel',
#  'ikbalkaya': 'Sports',
#  'lastdoor_tr': 'Food',
#  'dengemerkezi': 'Mom and children',
#  'edisdeposu': 'Art',
#  'akyuzmobilyaurfa': 'Art',
#  'solcugazete': 'Mom and children',
#  'avmorion': 'Fashion',
#  'fizikseltiyatro': 'Art',
#  'gurmerehber': 'Travel',
#  'gursubeltr': 'Entertainment',
#  'sahanepazar': 'Art',
#  'swipeline': 'Fashion',
#  'ahmethamdigork': 'Entertainment',
#  'expertyol': 'Mom and children',
#  'araskarafil': 'Entertainment',
#  'tepebasibeltr': 'Entertainment',
#  'kumpirbox': 'Mom and children',
#  'hedefbeytotel': 'Travel',
#  'seyitaliofficial': 'Entertainment',
#  'armonipark': 'Fashion',
#  'erzincansuleymankaraman': 'Entertainment',
#  'cebirecep': 'Tech',
#  'omsvibro': 'Art',
#  'alacatibeachresort': 'Travel',
#  'elkon_official': 'Entertainment',
#  'kaan.sekban': 'Entertainment',
#  'flotalmirror': 'Art',
#  'thelevanttahinier': 'Mom and children',
#  'zodyakli': 'Fashion',
#  'beiniztv': 'Travel',
#  'mesutscl': 'Travel',
#  'umraniyebeltr': 'Sports',
#  'muratacilimranli': 'Tech',
#  'imamoglu.belediyesi': 'Mom and children',
#  'jumbokunefetr': 'Sports',
#  'gulgrupgayrimenkul': 'Mom and children',
#  'soyturkrabia': 'Mom and children',
#  'pekcetintemizlik': 'Fashion',
#  'psikezone': 'Mom and children',
#  'donerci_serkan_usta': 'Food',
#  'mirdellav': 'Mom and children',
#  'iyigelir.biz': 'Art',
#  'durumle': 'Travel',
#  '3durak': 'Sports',
#  'roofgamesstudio': 'Art',
#  'konseptkutucom': 'Art',
#  'uras.benlioglu': 'Fashion',
#  'yemekcom': 'Fashion',
#  'ipekozagan': 'Fashion',
#  'ozeltanyeri': 'Sports',
#  'hakkiakdenizz': 'Mom and children',
#  'mekoglobal': 'Tech',
#  'datcabelediyesi': 'Mom and children',
#  'tkdkordu': 'Travel',
#  'yelkenrest': 'Food',
#  'suleymansarilar': 'Fashion',
#  '___daire___': 'Tech',
#  'iremhlvcioglu': 'Fashion',
#  'uberkuloz': 'Art',
#  'fdnsirketlergrubu': 'Food',
#  'podyumsanatmahal': 'Art',
#  '3eeemedya': 'Tech',
#  'akinyucel': 'Tech',
#  'sky_uk': 'Travel',
#  'kesifmekan': 'Sports',
#  'whatupmell': 'Fashion',
#  'nedimkaplann': 'Travel',
#  'ozdilekusakavm': 'Entertainment',
#  'trendmobilyacom': 'Fashion',
#  'beka_beka_anaokulu': 'Mom and children',
#  'turkiyedagcilik': 'Tech',
#  'leylasapmazz': 'Mom and children',
#  'turkistanpazari': 'Tech',
#  'hyattregencyistanbulatakoy': 'Travel',
#  'gercekmutfak': 'Food',
#  'tolgasaritas': 'Art',
#  'gayretmakina': 'Tech',
#  'gzonemag': 'Fashion',
#  'lineersoft': 'Sports',
#  'desimerkez': 'Fashion',
#  'tavukdunyasikariyer': 'Food',
#  'akgunwalker': 'Travel',
#  'didemeryarunlu': 'Fashion',
#  'asaspen.veratec': 'Sports',
#  'ezgi_basaran': 'Sports',
#  'applegurgencler': 'Food',
#  'turktraktorkariyer': 'Tech',
#  'nihatatli.tr': 'Fashion',
#  'guncesanattiyatrosu': 'Art',
#  'talha_karci': 'Sports',
#  'meltem.hastanesi': 'Health and lifestyle',
#  'diyetisyengamzealtinay': 'Health and lifestyle',
#  'canyucetas': 'Sports',
#  'kaanurgancioglu': 'Sports',
#  'gursueraykirtasiye': 'Art',
#  'dinersclubtr': 'Travel',
#  'stonebarizmir': 'Travel',
#  'rocscoffee': 'Food',
#  'ayhancanguven': 'Sports',
#  'ezomola': 'Mom and children',
#  'unuttumsanmacom': 'Fashion',
#  'hotech_ecosystem': 'Tech',
#  'bingolbel': 'Tech',
#  'cengizsemercio': 'Art',
#  'bskulgurgokhan_': 'Sports',
#  'veritameyve': 'Sports',
#  'bekiraltantr': 'Sports',
#  'vmilor': 'Mom and children',
#  'pylsmn': 'Entertainment',
#  'duzceguvencomtr': 'Tech',
#  'argonotlar.sanat': 'Art',
#  'cilemakar': 'Sports',
#  'novotel_bosphorus': 'Travel',
#  'yuncualimagazalari': 'Fashion',
#  'bahar_eli': 'Art',
#  'turkiyesualtisporlari': 'Tech',
#  'operaistanbul': 'Mom and children',
#  'rengarenkkanal': 'Entertainment',
#  'guronimobilya': 'Art',
#  'ktheventagency': 'Tech',
#  'lutfusavas': 'Mom and children',
#  'cookluhayat': 'Art',
#  'birayetarapca': 'Tech',
#  'buyukdere35': 'Fashion',
#  'milliyiyici': 'Mom and children',
#  'muhikucom': 'Art',
#  'izmirekolhastanesi': 'Health and lifestyle',
#  'fundafashion': 'Entertainment',
#  'dilart.design': 'Fashion',
#  'eurovisn_turkey': 'Tech',
#  'ibrahim__varli': 'Mom and children',
#  'tarsusbelediyesi': 'Mom and children',
#  'pinarhepyanimda': 'Mom and children',
#  'sporsuncom': 'Sports',
#  'btginsaat': 'Tech',
#  'izmiretkinlikhaberleri': 'Travel',
#  'akifergurumtr': 'Mom and children',
#  'boztaspremium': 'Travel',
#  '3d_maket': 'Tech',
#  'tekinozalit': 'Art',
#  'elvanreklamtr': 'Mom and children',
#  'alikerimdiler': 'Entertainment',
#  'tufanlarkuyumculuk': 'Fashion',
#  'sendeyapsana': 'Art',
#  'arifibrahimoff': 'Mom and children',
#  'alpatayazilim': 'Tech',
#  'kasaphansteakhouse': 'Travel',
#  'seturdutyfree': 'Travel',
#  'ozkocengin': 'Art',
#  'novikovbodrum': 'Travel',
#  'yedibilgeler': 'Mom and children',
#  'caddekultursanat': 'Art',
#  'weareomgteam': 'Fashion',
#  'bullentoz': 'Entertainment',
#  'huseyinkabisteke': 'Tech',
#  'takviyegiller': 'Travel',
#  'herseyyanimda': 'Fashion',
#  '_helinkandemir': 'Fashion',
#  'ipekpamuk': 'Tech',
#  'gsb_erzincan': 'Sports',
#  'seyirdernegi': 'Mom and children',
#  'eformspormerkezi': 'Sports',
#  'hakansuer41': 'Entertainment',
#  'medicasimple': 'Travel',
#  'murat.besikci': 'Sports',
#  'zadevital': 'Art',
#  'gokhanozoguz': 'Sports',
#  'fishorg': 'Fashion',
#  'ahlparkavm': 'Entertainment',
#  'galipensarioglu': 'Fashion',
#  'acarflowers': 'Art',
#  'selcuklubel': 'Mom and children',
#  'onlembebekbezi': 'Mom and children',
#  'liqui_moly_turkey': 'Tech',
#  'magnumenerji': 'Tech',
#  'kulabelediyesi': 'Mom and children',
#  'aleynaclsknn': 'Mom and children',
#  'ikicay': 'Travel',
#  'lemonadeagency': 'Tech',
#  'unolezzetleri': 'Food',
#  'pelinyarr': 'Travel',
#  'viastudio': 'Art',
#  'hyattregencyizmir_istinyepark': 'Travel',
#  'mentos_tr': 'Entertainment',
#  'meliskaracam': 'Sports',
#  'dedemankonyahotel': 'Travel',
#  '01burdaavm': 'Entertainment',
#  'minimokirtasiye': 'Art',
#  'pendikbelediyesi': 'Mom and children',
#  'arkas_spor': 'Sports',
#  'normholding': 'Tech',
#  'ahmetipeksucuklariafyon': 'Mom and children',
#  'medyaevi_iletisim': 'Tech',
#  'mbbkulturas': 'Travel',
#  'byelergumus': 'Mom and children',
#  'ozanyigitt': 'Travel',
#  'miniaturkmuzesi': 'Art',
#  'ozgeyagizz': 'Entertainment',
#  'nanopax_com': 'Tech',
#  'roketsan': 'Art',
#  'kadikoyemek': 'Entertainment',
#  'ozaysendir': 'Entertainment',
#  'ferideozdincc': 'Entertainment',
#  'ecift': 'Sports',
#  'eklerciumit': 'Mom and children',
#  'estehair': 'Sports',
#  'izmirhim': 'Travel',
#  'demiirhaan': 'Entertainment',
#  'ketebe': 'Mom and children',
#  'pozitif.dusunceler': 'Mom and children',
#  'opdrerdemzengin': 'Fashion',
#  'gufojewelry': 'Fashion',
#  'hamzaefendi': 'Art',
#  'imok_studio': 'Art',
#  'ysdistanbul': 'Entertainment',
#  'beachandbeyondswimwear': 'Fashion',
#  'richmondpamukkale': 'Fashion',
#  'rizepazarbelediyesi': 'Mom and children',
#  'vineturkiyem': 'Tech',
#  'ikizlerbebefethiye': 'Mom and children',
#  'trtworld': 'Sports',
#  'ozgefiskin': 'Entertainment',
#  'engeenergy': 'Mom and children',
#  'biostoretr': 'Fashion',
#  'edakok59': 'Entertainment',
#  'avmpomelon': 'Fashion',
#  'sait.restaurant': 'Food',
#  'evimin.yemekleri': 'Mom and children',
#  'ladymiena': 'Fashion',
#  'dokusanatatolyesi': 'Art',
#  'alvisajanss': 'Tech',
#  'birunitiyatro': 'Art',
#  'ugursengulx': 'Entertainment',
#  'kemerlizimba': 'Travel',
#  'drenginocal': 'Tech',
#  'patara.well': 'Fashion',
#  'barbarosfarm': 'Fashion',
#  'ataguroffice': 'Entertainment',
#  'ankaranobeltipkitabevleri': 'Mom and children',
#  'arminesiirtpark': 'Fashion',
#  'bancocomtr': 'Food',
#  'akbarkodetiket': 'Sports',
#  'karsiyakabelediyesi': 'Mom and children',
#  'simaybarlass': 'Travel',
#  'erdogantok55': 'Tech',
#  'levonbagis': 'Tech',
#  'quartzclinique': 'Health and lifestyle',
#  'porlandgastro': 'Food',
#  'dyt.psk.bilgesakli': 'Mom and children',
#  'dericompany': 'Entertainment',
#  'keciorenbelediyesi06': 'Mom and children',
#  'nergiscorakci': 'Sports',
#  'ontangrup': 'Travel',
#  'katalportmarin': 'Travel',
#  'primemallantakya': 'Travel',
#  'umit_ozlale': 'Sports',
#  'lokmacafe': 'Entertainment',
#  'drhalilibrahimtekin': 'Art',
#  'deppo_avantaj': 'Tech',
#  'meltem.kursunlu': 'Mom and children',
#  'akhisarpresshaber': 'Travel',
#  'grisahne': 'Entertainment',
#  'besaygold': 'Sports',
#  'bungalovoteller': 'Travel',
#  'mersinsensin': 'Art',
#  'biancaboya': 'Art',
#  'yegezokuyaz': 'Art',
#  'cemseymen': 'Sports',
#  'prohealthgenetictests': 'Travel',
#  'erenkoy_danismanlik': 'Fashion',
#  'ayvalikescbilisim': 'Tech',
#  'thecompanytr': 'Art',
#  'iyigelecekelcileri': 'Mom and children',
#  'nevzatozkur0': 'Entertainment',
#  'denizlibbld': 'Fashion',
#  'cibalikapibalikcisi': 'Art',
#  'pak_metal': 'Sports',
#  'tavtechnologies': 'Tech',
#  'malatyapark': 'Sports',
#  'onurkuyumcu1919': 'Fashion',
#  'poyrazotomotiv': 'Tech',
#  'ninovaparkavm': 'Entertainment',
#  'drderyacan': 'Sports',
#  'primepuritypep': 'Tech',
#  'galenikecza': 'Art',
#  'milangaz': 'Mom and children',
#  'mediviasaglikgrubu': 'Travel',
#  'tulayerciyaskayaa': 'Sports',
#  'kurulusdizisi': 'Travel',
#  'nurgulyesilcayy': 'Sports',
#  'selinayalcn': 'Travel',
#  'calgontr': 'Mom and children',
#  'mplusturkiye': 'Tech',
#  'antmarealacati': 'Tech',
#  'duzicibld': 'Travel',
#  'assosdiamond': 'Fashion',
#  'gulseli.com.tr': 'Fashion',
#  'iremsak': 'Tech',
#  'zulaoyun': 'Mom and children',
#  'ozdilekboluavm': 'Entertainment',
#  'everfastenings': 'Sports',
#  'ozakgokturk': 'Sports',
#  'pelinkarahan': 'Mom and children',
#  'kerimsabanci': 'Art',
#  'fatmasamsayilmaz': 'Tech',
#  'drbrkzks': 'Fashion',
#  'ciftelerbelediyesi': 'Mom and children',
#  'serangocer': 'Tech',
#  'hisliseyler': 'Mom and children',
#  'richhousebistro': 'Food',
#  'nurullahsavasresmi': 'Sports',
#  'yfatihcoban': 'Sports',
#  'boschturkiyekariyer': 'Tech',
#  'yachtmurat': 'Tech',
#  'cetinkayapano': 'Travel',
#  'yoldabiblog': 'Mom and children',
#  'limak.hotels': 'Travel',
#  'eminoguzcelebi': 'Travel',
#  'sailturkiyeracing': 'Travel',
#  'kronospan': 'Sports',
#  'defneilgaz.com.tr': 'Fashion',
#  'seyfidingil': 'Fashion',
#  'atalaraleyna': 'Sports',
#  '253binyasin': 'Food',
#  'tulinnalbayrak': 'Art',
#  'reiskuyumculuk': 'Fashion',
#  'dijiatolye': 'Travel',
#  'antolojiankara': 'Tech',
#  'girafestore': 'Art',
#  'profdrmuratbas': 'Art',
#  'kendinemuzisyen': 'Health and lifestyle',
#  'didembalikofficial': 'Entertainment',
#  'zpor': 'Sports',
#  'aquayasamofficial': 'Entertainment',
#  'oguzhankapilar': 'Art',
#  'westparkoutlet': 'Entertainment',
#  'odyomedbursa': 'Travel',
#  'pluscomiletisim': 'Tech',
#  'ulubeybelediyesi': 'Mom and children',
#  'galvinnisantasi': 'Fashion',
#  'yoldalogistics': 'Art',
#  'mesdokum': 'Mom and children',
#  'cizmecikedi': 'Art',
#  'koleksiyonerberber': 'Mom and children',
#  'gurhanaltundasar': 'Entertainment',
#  'ankaragucufp': 'Mom and children',
#  'technical_sharing': 'Tech',
#  'idaorgonite': 'Sports',
#  'virahabercom': 'Fashion',
#  'uykudunyasicom': 'Food',
#  'beymenclub': 'Travel',
#  'theboviera': 'Art',
#  'logoyazilimkariyer': 'Tech',
#  'tijenaktay': 'Mom and children',
#  'mastercardturkiye': 'Sports',
#  'itef_istanbul': 'Entertainment',
#  'buyukekerbijon': 'Travel',
#  'kosbsocial': 'Entertainment',
#  'bisalt': 'Tech',
#  'antmodern': 'Art',
#  'trendyolhizlimarket': 'Tech',
#  'transparentproductions': 'Sports',
#  'acibadem.international': 'Mom and children',
#  'mervekutlu': 'Travel',
#  'dirim.metal': 'Tech',
#  'rahmi.gencer': 'Sports',
#  'hamzayilmazmucevherat': 'Art',
#  '1001sanat': 'Art',
#  'gaziantepbeld': 'Fashion',
#  'aslanegegrup': 'Art',
#  'sabanozubelediyesi': 'Mom and children',
#  'flotalofficial': 'Entertainment',
#  'guralpremier': 'Sports',
#  'debuttiyatro': 'Art',
#  'yorkkadikoy': 'Entertainment',
#  'spitalispecialbahceci': 'Sports',
#  'ecebelenn': 'Mom and children',
#  'ersinceliq': 'Art',
#  'greysatelier': 'Tech',
#  'sarigolbelediyesi': 'Mom and children',
#  'umut.cigercisi': 'Sports',
#  'ikuakingucoditoryumu': 'Fashion',
#  'tcvanvaliligi': 'Mom and children',
#  'sivilsayfalar': 'Tech',
#  'sestri.lifestyle': 'Fashion',
#  'crafttiyatro': 'Art',
#  '1983beyoglu': 'Art',
#  'ardahalil': 'Art',
#  'sinemunsal': 'Fashion',
#  'baziseylertiyatrosu': 'Art',
#  'ipekkyazici': 'Art',
#  'junkeralsancak': 'Travel',
#  'bihterkocc': 'Tech',
#  'alinuraktas': 'Sports',
#  'forkidstyle': 'Mom and children',
#  'mesudiyelicom': 'Tech',
#  'hurriyetkelebek': 'Mom and children',
#  'turktelekombasketbol': 'Tech',
#  'drselcukyuce': 'Mom and children',
#  'andacyesilyurt': 'Fashion',
#  'yigitcanic': 'Tech',
#  'gulercetingoz': 'Sports',
#  'paktplus': 'Fashion',
#  'tiyatrokast': 'Art',
#  'akutdernegi': 'Mom and children',
#  'telesuresigorta': 'Art',
#  'aperinastudios': 'Tech',
#  'yenicekoyu43': 'Tech',
#  'gencliksporbak': 'Sports',
#  'gittibu_com': 'Art',
#  'farukerdem': 'Travel',
#  'zamanekahvesi': 'Food',
#  'ismailsenol': 'Tech',
#  'senpilic': 'Fashion',
#  'alternatifmarket': 'Sports',
#  'sehernigiz': 'Art',
#  'ozulkutipmerkezi': 'Tech',
#  'acunilicali': 'Mom and children',
#  'adnanturankb': 'Tech',
#  'ckalebelediye': 'Mom and children',
#  'nesrullah.tanglay': 'Sports',
#  'aslieliftanugursamanci': 'Entertainment',
#  'tonyhawk': 'Sports',
#  'pursuailesi': 'Mom and children',
#  'call_me_mumsy': 'Travel',
#  'kocamaar': 'Tech',
#  'retinagraphic': 'Art',
#  'winblocktr': 'Tech',
#  'multiplayertv': 'Travel',
#  'beyoglubld': 'Travel',
#  'm0rtyrick': 'Art',
#  'icindekocvar': 'Tech',
#  'gshocktr': 'Tech',
#  'beykozkultursanat': 'Art',
#  'ecmelsoylu': 'Entertainment',
#  'tevadimadim': 'Sports',
#  'bursayasam': 'Travel',
#  'maden_belediyesi': 'Mom and children',
#  'trgyguler': 'Sports',
#  'metanucreative': 'Tech',
#  'upl.turkey': 'Tech',
#  'celebizadeonline': 'Fashion',
#  'uclermarket': 'Sports',
#  'toyganavanoglu': 'Entertainment',
#  'agacin.izinde': 'Art',
#  'ozhotelstr': 'Travel',
#  'safamecomercial': 'Fashion',
#  '_felxtv_': 'Travel',
#  'dentsuadiye': 'Entertainment',
#  'tiyatroboyalikus': 'Art',
#  'basaritelematik': 'Tech',
#  'ciplakayaklarkumpanyasi': 'Food',
#  'mahmut_mirkelamm': 'Mom and children',
#  'tekincreativemedia': 'Tech',
#  'tasovabelediyesi': 'Mom and children',
#  'supra_hubs': 'Tech',
#  'mandalajans': 'Tech',
#  'ebcinege': 'Mom and children',
#  'adilyildirimyazar': 'Tech',
#  'asiyansanat': 'Art',
#  'muharremakcadurak': 'Sports',
#  'donercibekirzade': 'Mom and children',
#  'sherwoodresorts': 'Sports',
#  'grandyaziciclubturban': 'Art',
#  'birbuketmuge': 'Mom and children',
#  'bozcaadabld': 'Travel',
#  'dijitalsosyalmedyam': 'Tech',
#  'adel.turkiye': 'Tech',
#  'benim.odam': 'Food',
#  'manolyaurkan': 'Entertainment',
#  'donerciorhan': 'Food',
#  'akcoat_official': 'Entertainment',
#  'evimdeterapi': 'Tech',
#  'zettdekor': 'Tech',
#  'agrotar_turkey': 'Tech',
#  'pasinlerbld': 'Travel',
#  'tipografi': 'Art',
#  'nurettinsonmez': 'Mom and children',
#  'tubabustun.official': 'Entertainment',
#  '35likmeyhaneizmir': 'Sports',
#  'stilac': 'Health and lifestyle',
#  'boyrazizolasyon': 'Tech',
#  'dentisteturkiye': 'Tech',
#  'altinayteknoloji': 'Tech',
#  'avbakidemirbas': 'Sports',
#  'diyeting': 'Health and lifestyle',
#  'superfitshoes_turkey': 'Tech',
#  'diyetebasliyorumcom': 'Travel',
#  'pizzastationturkiye': 'Tech',
#  'adiyamanvalilik': 'Art',
#  'cevrecienerjidernegi': 'Mom and children',
#  'novaarsaofficial': 'Fashion',
#  'rubisaglik': 'Fashion',
#  'denizbaysal_': 'Fashion',
#  'drtubagunebak': 'Sports',
#  'rotekstekstil': 'Tech',
#  'burkaystagram': 'Entertainment',
#  'yenisehir.bel.tr': 'Health and lifestyle',
#  'pelinnarint': 'Fashion',
#  'partibutik': 'Travel',
#  'simalcerenn': 'Mom and children',
#  'buklatur': 'Travel',
#  'oxabrasive': 'Sports',
#  'marka.333': 'Mom and children',
#  'gulsjourney': 'Mom and children',
#  'gdz_edas': 'Entertainment',
#  'turyap': 'Tech',
#  'ugurakkafa': 'Entertainment',
#  'tiesfed': 'Sports',
#  'zabeyazgul': 'Art',
#  'fordotosan': 'Tech',
#  'sevilayyilman': 'Mom and children',
#  'instakocaali': 'Art',
#  'regispatent': 'Tech',
#  'lezzetborsasi': 'Food',
#  'netafimturkiye': 'Tech',
#  'evreninmatematigi': 'Mom and children',
#  'seyhanlarmarket': 'Sports',
#  'relaxmodeofficial': 'Fashion',
#  'ataberk.dogan': 'Art',
#  'meliketatar': 'Art',
#  'tohumgubre': 'Sports',
#  'ebebek': 'Mom and children',
#  'mabbelsatolye': 'Travel',
#  'hopiapp': 'Fashion',
#  'tariszeytinyagi': 'Mom and children',
#  'tahsinhasoglu': 'Art',
#  'longosphere': 'Fashion',
#  'peymankuruyemis': 'Mom and children',
#  'trendylarahotel': 'Travel',
#  'pedasled': 'Fashion',
#  'besiktasshipyard': 'Sports',
#  'puccito': 'Food',
#  'malatyakultursosyal': 'Travel',
#  'sofosistanbul': 'Entertainment',
#  'devrimyakut': 'Art',
#  'forevernewturkiye': 'Tech',
#  'valigokmencicek_': 'Sports',
#  'akbanksanat': 'Art',
#  'isaleticom': 'Tech',
#  'veli.gok32': 'Sports',
#  'trio_deniz_official': 'Entertainment',
#  'mcengizbozkurt': 'Sports',
#  'istanbulalpplastik': 'Entertainment',
#  'pelinsutilki': 'Fashion',
#  'iamemrecaliskan': 'Art',
#  'ismailgeduz': 'Mom and children',
#  'selfycomtr': 'Mom and children',
#  'mstismakinalari': 'Tech',
#  'studio.oyunculari': 'Entertainment',
#  'nexuskuafor': 'Fashion',
#  'cznburak': 'Sports',
#  'etidanismanlik': 'Fashion',
#  'yildizgaz': 'Tech',
#  'bademlebuduk': 'Mom and children',
#  'sayginbaykaracom': 'Sports',
#  'onder.sayan': 'Sports',
#  'tiyatroumay': 'Art',
#  'maraskaski': 'Fashion',
#  'bebedorturkey': 'Mom and children',
#  'jumboturkiye': 'Fashion',
#  'alacabld': 'Travel',
#  'bs_forklift': 'Tech',
#  'superfm': 'Sports',
#  'yagizkurtulusy': 'Entertainment',
#  'yasemoz88': 'Sports',
#  'thermexturkiye': 'Tech',
#  'polarisayakkabi': 'Fashion',
#  'edremitbelediye': 'Travel',
#  'dr.yasirgozu': 'Entertainment',
#  'middelrestaurant': 'Food',
#  'mtmofamily': 'Fashion',
#  'yelizyesilmen': 'Sports',
#  'sumerpark_avm': 'Fashion',
#  'sozerinsaatorhangazi': 'Tech',
#  'digitalaths': 'Tech',
#  'gulcinsant': 'Fashion',
#  'endlessaksuluayakkabi': 'Fashion',
#  'minisoturkey': 'Tech',
#  'aysatiyatro': 'Art',
#  'artlineturkiye': 'Tech',
#  'montel.official': 'Entertainment',
#  'dizayngroup': 'Travel',
#  'asliafsaroglu': 'Art',
#  'karefilm': 'Entertainment',
#  'moc_coffeeofficial': 'Entertainment',
#  'talyatasarimtr': 'Mom and children',
#  'arguvanbelediyesi': 'Mom and children',
#  'cengelofficial': 'Entertainment',
#  'ekulak': 'Travel',
#  'gokgunnec': 'Mom and children',
#  'arzumkoyuncu': 'Entertainment',
#  'fiyuutr': 'Sports',
#  'aynesgida': 'Food',
#  'oyuncusendika': 'Entertainment',
#  'jehanbarbur': 'Entertainment',
#  'rafadantayfa': 'Mom and children',
#  'basf_tarim_tr': 'Sports',
#  'ardesenbelediyesi': 'Mom and children',
#  'kuirfest': 'Sports',
#  'olips_tr': 'Mom and children',
#  'muzegazhane': 'Art',
#  'ondibilisim': 'Tech',
#  'gazihastanesi': 'Health and lifestyle',
#  'gelinevi_tv': 'Fashion',
#  'heyceyn': 'Tech',
#  'tekhnelogos': 'Tech',
#  'petadijital': 'Mom and children',
#  'gustogiyim': 'Fashion',
#  'akasyaa_avm': 'Entertainment',
#  'arslangurerr': 'Fashion',
#  'dr.turhanguldas': 'Entertainment',
#  'orcundalarslan': 'Fashion',
#  'alldaycharm': 'Fashion',
#  'mxnsturkey': 'Tech',
#  'talaycihan': 'Sports',
#  'kutuphane79': 'Entertainment',
#  'sevketcoruh': 'Mom and children',
#  'aliyerlikaya_': 'Travel',
#  'sacimsacinolsun': 'Entertainment',
#  'mhmtaktrk': 'Tech',
#  'jessicamayofficial': 'Entertainment',
#  'ceturturkiye': 'Tech',
#  'elifatalar': 'Fashion',
#  'profdrmurataksoy': 'Art',
#  'gastrogezgin': 'Travel',
#  'axisistanbulavm': 'Entertainment',
#  'petopytr': 'Mom and children',
#  'berkaytulumbaci': 'Art',
#  'evdekolay': 'Mom and children',
#  'viteltr': 'Travel',
#  'merveozbeyofficial': 'Entertainment',
#  'no224creative': 'Tech',
#  'goksu_avm': 'Fashion',
#  'baharakinci': 'Art',
#  'mengenbelediyesi1414': 'Mom and children',
#  'batuconcept': 'Art',
#  'ih_korkmaz': 'Art',
#  'piculetstore': 'Fashion',
#  'kadinozsavunma': 'Entertainment',
#  'borckabld': 'Travel',
#  'biryemekiste': 'Tech',
#  'evkokusu': 'Mom and children',
#  'maison_turkey': 'Tech',
#  'ceyhanbeltr': 'Sports',
#  'daricabelediyesi': 'Mom and children',
#  'korayaydintr': 'Tech',
#  'izmiretkinlikleri': 'Travel',
#  'labrandaephesusprincess': 'Fashion',
#  'sanliurfabld': 'Entertainment',
#  'eczacibasisporkulubu': 'Sports',
#  'gulrizandic': 'Mom and children',
#  'mustafatokat77': 'Sports',
#  'iqaluminiumsystems': 'Tech',
#  'carpetartofficial': 'Entertainment',
#  'wcollection': 'Sports',
#  'kutu.baligi': 'Mom and children',
#  'gimatmarketlerzincirii': 'Art',
#  'jalpersanofficial': 'Entertainment',
#  'luleburgazbld': 'Travel',
#  'paragrafmedya': 'Tech',
#  'ozgurcamurlu': 'Entertainment',
#  'ekimsanat': 'Art',
#  'fixgross': 'Entertainment',
#  'konyafarukgulluoglu': 'Sports',
#  'yiyomfoodblogger': 'Mom and children',
#  'dorukyazilim': 'Tech',
#  'mantragastropub': 'Food',
#  'yudumyag': 'Sports',
#  'kiralarsin': 'Fashion',
#  'orhansef': 'Fashion',
#  'merterenbulbul1': 'Entertainment',
#  'antaresavm': 'Travel',
#  'mutfakta_bebek_var': 'Mom and children',
#  'kaanvarli': 'Sports',
#  'finikebelediye': 'Mom and children',
#  'brotherturkey': 'Tech',
#  'justfeelingstudio': 'Art',
#  'gezsenbatman': 'Travel',
#  'yapimboyle': 'Entertainment',
#  'quickchina': 'Tech',
#  'amazon.tr': 'Entertainment',
#  'ihealthsaglik': 'Travel',
#  'alicanaytekin': 'Art',
#  'elegansgrupkagitcilik': 'Tech',
#  'elementlogistics': 'Tech',
#  'gumus_bahattin': 'Art',
#  'bengikurtcebe': 'Mom and children',
#  'asyaalizaude': 'Travel',
#  'solargezi': 'Travel',
#  'fevzizirhlioglu': 'Fashion',
#  'kozantepkunefe': 'Art',
#  'kasapoglu': 'Sports',
#  'fourestcalticak': 'Tech',
#  'altinorumcek': 'Sports',
#  'arzuakbaszor': 'Sports',
#  'ahmettatlises': 'Entertainment',
#  'didemsoydan': 'Mom and children',
#  'acemmarket': 'Mom and children',
#  'idasosyalmedya': 'Tech',
#  'pertekbelediyesi': 'Mom and children',
#  'fixpacktr': 'Tech',
#  'feriyeistanbul': 'Entertainment',
#  'okanerertugrul': 'Mom and children',
#  'isikcelik.a.s': 'Tech',
#  'dpperfumum': 'Fashion',
#  'nilaybale': 'Fashion',
#  'fahrigediz': 'Travel',
#  'vanedremitbld': 'Travel',
#  'ebruuyucell': 'Mom and children',
#  'menopozveyasamtr': 'Tech',
#  'altekyapi': 'Travel',
#  'thermomixtr': 'Art',
#  'bitaksi': 'Travel',
#  'antalyakultursanat': 'Travel',
#  'sergenozn': 'Entertainment',
#  'cemuzan': 'Art',
#  'enka_insaat_official': 'Entertainment',
#  'socialbrandstr': 'Art',
#  'alialtuntasbaskan': 'Travel',
#  'silivritvtr': 'Mom and children',
#  'vimerang': 'Tech',
#  'omurgedik': 'Travel',
#  'richmondnua': 'Fashion',
#  'psikologmerkezi': 'Tech',
#  'divan_sarraf': 'Fashion',
#  'baykushbaby': 'Mom and children',
#  'kademe.tr': 'Mom and children',
#  'motolojim': 'Sports',
#  'guven_ovun': 'Tech',
#  'argoalsancak': 'Travel',
#  'kelambazblog': 'Mom and children',
#  'grand_cevahir_hotel': 'Travel',
#  'aysebilgeselcuk': 'Mom and children',
#  'dilekcesur_': 'Tech',
#  'agoraavm_antalya': 'Mom and children',
#  'tugkangonultas': 'Sports',
#  'roubloff_turkey': 'Tech',
#  'prof.dr.halilalis': 'Art',
#  'driclortr': 'Travel',
#  'tiyatroterminal': 'Art',
#  'cartmancase': 'Travel',
#  'farkyaratanlarsabancivakfi': 'Mom and children',
#  'kosekahve': 'Food',
#  'kadikoyboasahne': 'Entertainment',
#  'kdzereglitso': 'Art',
#  'pepsiturkiye': 'Tech',
#  'estetikeskisehir': 'Sports',
#  'itsumijapon': 'Sports',
#  'dyt.omercanyorulmaz': 'Art',
#  'kucukkulup_': 'Mom and children',
#  'tugrulkuyumculuk': 'Fashion',
#  'eczozgurozel': 'Tech',
#  'merrellturkiye': 'Tech',
#  'rivadent_maltepe': 'Fashion',
#  'gastronometro': 'Art',
#  'seyhan_ekspres': 'Sports',
#  'minikseyler_': 'Mom and children',
#  'kasimpasask': 'Travel',
#  'otokiosktr': 'Tech',
#  'karasugold': 'Sports',
#  'mostphotos': 'Art',
#  'swothospitality': 'Tech',
#  'kuff.yeldegirmeni': 'Tech',
#  'birceakalay': 'Sports',
#  'aynurtartan': 'Travel',
#  'brixtonturkiye': 'Tech',
#  'reklamcikafasi': 'Tech',
#  'utkucubukcuoglu': 'Sports',
#  'ucan_baba': 'Mom and children',
#  'rehberle': 'Travel',
#  'ntaslicay': 'Travel',
#  'dogukan_kilic': 'Mom and children'}
